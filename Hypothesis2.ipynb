# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanask/Assignments_ExcelR_Suhana/blob/main/Hypothesis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
from scipy import stats
import pandas as pd

# %% [markdown]
# null hypothesis- no difference in average TAT among the labs

# %% [markdown]
# alternate hypothesis- there is difference in average TAT among the labs

# %%
df = pd.read_csv('LabTAT.csv')
df
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
df.isnull()
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0           False         False         False         False
# 1           False         False         False         False
# 2           False         False         False         False
# 3           False         False         False         False
# 4           False         False         False         False
# ..            ...           ...           ...           ...
# 115         False         False         False         False
# 116         False         False         False         False
# 117         False         False         False         False
# 118         False         False         False         False
# 119         False         False         False         False
#
# [120 rows x 4 columns]

# %%
df.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
lab1 = 'Laboratory 1'
L1 = df[[lab1]]

# %%
L1
# Out:
#      Laboratory 1
# 0          185.35
# 1          170.49
# 2          192.77
# 3          177.33
# 4          193.41
# ..            ...
# 115        178.49
# 116        176.08
# 117        202.48
# 118        182.40
# 119        182.09
#
# [120 rows x 1 columns]

# %%
lab2 = 'Laboratory 2'
L2 = df[[lab2]]
lab3 = 'Laboratory 3'
L3 = df[[lab3]]
lab4 = 'Laboratory 4'
L4 = df[[lab4]]

# %%
L2
# Out:
#      Laboratory 2
# 0          165.53
# 1          185.91
# 2          194.92
# 3          183.00
# 4          169.57
# ..            ...
# 115        170.66
# 116        183.98
# 117        174.54
# 118        197.18
# 119        215.17
#
# [120 rows x 1 columns]

# %%
L3
# Out:
#      Laboratory 3
# 0          176.70
# 1          198.45
# 2          201.23
# 3          199.61
# 4          204.63
# ..            ...
# 115        193.80
# 116        215.25
# 117        203.99
# 118        194.52
# 119        221.49
#
# [120 rows x 1 columns]

# %%
L4
# Out:
#      Laboratory 4
# 0          166.13
# 1          160.79
# 2          185.18
# 3          176.42
# 4          152.60
# ..            ...
# 115        172.68
# 116        177.64
# 117        170.27
# 118        150.87
# 119        162.21
#
# [120 rows x 1 columns]

# %% [markdown]
# performing ANOVA to compare all the four labs

# %%
scipy.stats.f_oneway(L1, L2, L3, L4)
# Out:
# F_onewayResult(statistic=array([118.70421654]), pvalue=array([2.11567089e-57]))

# %% [markdown]
# since p-value<0.05, we reject the null hypothesis.

# %% [markdown]
# Hence, there is a significant difference in average TAT among the labs.
